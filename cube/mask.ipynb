# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("assets/test1.png")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

_, mask = cv2.threshold(gray, 170, 255, cv2.THRESH_BINARY)

kernel = np.ones((3,3), np.uint8)
mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)

plt.subplot(1, 2, 1)
plt.imshow(img)
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(mask)
plt.axis('off')
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_empty = cv2.imread("assets/digital-box.png")
img_obj = cv2.imread("assets/digital-box-w-obj.png")

plt.subplot(1, 2, 1)
plt.imshow(img_empty)
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_obj)
plt.axis('off')

plt.show()

# gray_empty = cv2.cvtColor(img_empty, cv2.COLOR_BGR2GRAY)
# gray_obj = cv2.cvtColor(img_obj, cv2.COLOR_BGR2GRAY)

# _, mask = cv2.threshold(gray, 170, 255, cv2.THRESH_BINARY)

# kernel = np.ones((3,3), np.uint8)
# mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
diff = cv2.absdiff(img_empty, img_obj)
plt.imshow(diff, cmap='gray')
plt.axis('off')
plt.show()

# normalized = cv2.normalize(diff, None, 0, 1, cv2.NORM_MINMAX)
# plt.imshow(normalized, cmap='gray')
# plt.show()

diff = cv2.cvtColor(diff, cv2.COLOR_BGR2GRAY)
mask = cv2.threshold(diff, 10, 255, cv2.THRESH_BINARY)[1]
mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)

plt.imshow(mask)
plt.axis('off')
plt.show()
