# %%
from LEDController import LEDController
from CameraController import CameraController

# %%
led = LEDController()

patt = led.get_empty_pattern()

# patt[0] = led.make_pixel(255,255,255,255)

patt = led.set_all(255,255,255,255)

led.display_pattern(patt)
# Out:
# /opt/anaconda3/envs/461project/lib/python3.11/site-packages/xled/security.py:96: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   algorithm = algorithms.ARC4(key)
# Current mode: {'mode': 'rt', 'detect_mode': 0, 'shop_mode': 0, 'code': 1000}
# <ApplicationResponse [1000]>

# %%
print(patt)
# Out:
# [b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\xff\xff\xff', b'\x ...

# %%
cam = CameraController()
# Out:
# EDSDK initialized.

# %%
cam.open_camera()
cam.capture_image()
# Out:
# Found 1 camera(s).
# Camera obtained.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cam.open_camera()
#       2 cam.capture_image()
#
# File ~/My Drive/SFU/CMPT 461/Project/WalmartRGB/src/CameraController.py:153, in CameraController.open_camera(self)
#     150 print("Camera obtained.")
#     152 # Open a session with the camera.
# --> 153 self._check(self.edsdk.EdsOpenSession(self.camera))
#     154 print("Session opened with camera.")
#
# File ~/My Drive/SFU/CMPT 461/Project/WalmartRGB/src/CameraController.py:72, in CameraController._check(self, err)
#      70 """Helper function to check for errors returned by the SDK functions."""
#      71 if err != 0:
# ---> 72     raise Exception("Error: 0x{:08X}".format(err))
#
# Exception: Error: 0x00000007
